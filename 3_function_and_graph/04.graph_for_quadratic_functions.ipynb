# %% [markdown]
# A function is a quadratic function when the function is of two variables. It is the of the form
# $$f(x) = ax^2+bx+c$$
# when a, b, and c are conttants and a≠0.<br><br>
#
# The quadratic fuction here gets 5 elements while generating a graph.
#
# - **a**, **b**, **c** are equal to the **a**, **b**, **c** from the function
# $$y = ax^2 + bx + c$$<br><br>
#
#
# A quadratic function also can be produced by while loop just as a linear function.
# - If you have x coordinates then you can get the y coordinates through caculation of the equation above.<br>
# - Set the x coordinates as the minimum value of the graph range, then increase x value by the value of dist and caculate y coordinates.<br>
# - Store x and y coordinates to the list.<br>
# - When x coordinates exceeds the maximum value of the graph range, break the while loop.

# %%
from matplotlib import pyplot as plt
"""
### Code from others ###

class QuadraticEquation:
    def __init__(self, a, b, c, dist=1, size=100):
        self.size = size
        self.xs = []
        self.ys = []
        
        x = -size
        
        while True:
            self.xs.append(x)
            self.ys.append((a * (x * x)) + (b * x) + c)
            x += dist
            if x > size:
                break
"""


# Declare QuadraticEquation that returns a graph for given quadratic function.
class QuadraticEquation:
    def __init__(self, a, b, c, dist=1, size=100):
        self.a = a
        self.b = b
        self.c = c
        self.dist = dist
        self.size = size
        self.xs = []
        self.ys = []
        
        x = -size

        while x < size:
            y = self.a*x**2 + self.b*x + self.c
            x = x+dist
            self.xs.append(x)
            self.ys.append(y)
            
            
    def show_graph(self): 
        plt.plot(self.xs, self.ys, '-')
        plt.grid(True)
        axes = plt.gca()
        axes.set_xlim([-self.size, self.size])
        axes.set_ylim([-self.size, self.size])
        plt.show()


# Let a = 1, b = 0 , c = 0, dist = 0.1, size = 10
# Show the graph using show-graph method.
QuadraticEquation(-2, 3, 4, 0.1, 10).show_graph()

# %%
from matplotlib import pyplot as plt

xs = [0, 2, 3, 4, 5]
ys = [0, 4, 1, 7, 5]


# Using 'plot' method with elements xs and ys, draw red line graph.
plt.plot(xs, ys, "-", color='red')
plt.grid(True)
axes = plt.gca()
axes.set_xlim([0, 5])
axes.set_ylim([0, 8])

plt.show()
